# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
import pickle
import streamlit as st
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r"C:\\Users\\jadha\\OneDrive\\Desktop\\PBL-project\\final_more_modified_student_performance_data.csv")
df
# Out:
#     Student ID              Name  Class  Marks   Family Background  \
# 0            1        Rahul More      9    NaN                 NaN
# 1            2    Aarav Deshmukh     10   62.0         Upper class
# 2            3        Rahul More     11   90.0                 NaN
# 3            4   Ananya Kulkarni      9    NaN  Upper-middle class
# 4            5     Vishal Chavan     10   60.0         Lower class
# ..         ...               ...    ...    ...                 ...
# 95          96     Meera Bhosale     12   89.0  Upper-middle class
# 96          97  Aishwarya Sawant     10    NaN         Lower class
# 97          98  Aishwarya Sawant     11   71.0         Upper class
# 98          99     Meera Bhosale     12   79.0  Upper-middle class
# 99         100       Arjun Joshi     10   66.0         Lower class
#
#      Family Educational Background  Attendance (%)   Behavior  \
# 0      Father high school graduate            90.0       Poor
# 1      Mother high school graduate             NaN  Excellent
# 2      Father high school graduate            85.0       Good
# 3      Father high school graduate            97.0    Average
# 4   Both parents college graduates            87.0  Excellent
# ..                             ...             ...        ...
# 95  Both parents college graduates            81.0       Good
# 96     Father high school graduate            97.0       Poor
# 97     Father high school graduate            86.0       Good
# 98     Mother high school graduate            87.0  Excellent
# 99  Both parents college graduates             NaN       Poor
#
#    Viva Performance Submission  ...           Hobby Academic Attributes  \
# 0              Good       Late  ...         Reading           Marks: 60
# 1         Excellent       Late  ...         Reading           Marks: 62
# 2           Average       Late  ...  Playing Tennis           Marks: 90
# 3              Good    On time  ...             NaN           Marks: 65
# 4               NaN    On time  ...  Playing Tennis           Marks: 60
# ..              ...        ...  ...             ...                 ...
# 95        Excellent       Late  ...  Playing Tennis                 NaN
# 96              NaN    On time  ...       Traveling           Marks: 82
# 97        Excellent       Late  ...  Playing Guitar           Marks: 71
# 98              NaN    On time  ...  Playing Guitar           Marks: 79
# 99             Poor        NaN  ...  Playing Tennis           Marks: 66
#
#     Behavioral Attributes           Socioeconomic Attributes  \
# 0   Time Management: Good        Socioeconomic: Middle class
# 1   Time Management: Good         Socioeconomic: Upper class
# 2   Time Management: Good        Socioeconomic: Middle class
# 3   Time Management: Good  Socioeconomic: Upper-middle class
# 4   Time Management: Good         Socioeconomic: Lower class
# ..                    ...                                ...
# 95  Time Management: Good                                NaN
# 96  Time Management: Good         Socioeconomic: Lower class
# 97  Time Management: Good         Socioeconomic: Upper class
# 98  Time Management: Good  Socioeconomic: Upper-middle class
# 99  Time Management: Good         Socioeconomic: Lower class
#
#       Psychological and Emotional             Technology Usage  \
# 0   Stress: Low, Confidence: High                          NaN
# 1   Stress: Low, Confidence: High  EdTech: High, Internet: Yes
# 2   Stress: Low, Confidence: High  EdTech: High, Internet: Yes
# 3   Stress: Low, Confidence: High  EdTech: High, Internet: Yes
# 4                             NaN  EdTech: High, Internet: Yes
# ..                            ...                          ...
# 95  Stress: Low, Confidence: High  EdTech: High, Internet: Yes
# 96  Stress: Low, Confidence: High  EdTech: High, Internet: Yes
# 97                            NaN  EdTech: High, Internet: Yes
# 98  Stress: Low, Confidence: High  EdTech: High, Internet: Yes
# 99  Stress: Low, Confidence: High  EdTech: High, Internet: Yes
#
#         Peer Interactions       Cognitive Attributes  \
# 0   Group Work: Excellent  Critical Thinking: Strong
# 1   Group Work: Excellent  Critical Thinking: Strong
# 2   Group Work: Excellent  Critical Thinking: Strong
# 3   Group Work: Excellent  Critical Thinking: Strong
# 4   Group Work: Excellent  Critical Thinking: Strong
# ..                    ...                        ...
# 95  Group Work: Excellent  Critical Thinking: Strong
# 96  Group Work: Excellent  Critical Thinking: Strong
# 97  Group Work: Excellent  Critical Thinking: Strong
# 98  Group Work: Excellent  Critical Thinking: Strong
# 99                    NaN  Critical Thinking: Strong
#
#         Communication Skills Learning Progression
# 0   Communication: Excellent  Improvement: Steady
# 1   Communication: Excellent  Improvement: Steady
# 2   Communication: Excellent  Improvement: Steady
# 3   Communication: Excellent  Improvement: Steady
# 4   Communication: Excellent  Improvement: Steady
# ..                       ...                  ...
# 95  Communication: Excellent  Improvement: Steady
# 96  Communication: Excellent  Improvement: Steady
# 97  Communication: Excellent  Improvement: Steady
# 98  Communication: Excellent  Improvement: Steady
# 99  Communication: Excellent  Improvement: Steady
#
# [100 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Student ID                     100 non-null    int64
#  1   Name                           100 non-null    object
#  2   Class                          100 non-null    int64
#  3   Marks                          77 non-null     float64
#  4   Family Background              90 non-null     object
#  5   Family Educational Background  100 non-null    object
#  6   Attendance (%)                 75 non-null     float64
#  7   Behavior                       76 non-null     object
#  8   Viva Performance               76 non-null     object
#  9   Submission                     78 non-null     object
#  10  Certification                  90 non-null     object
#  11  Achievements                   90 non-null     object
#  12  Hobby                          90 non-null     object
#  13  Academic Attributes            90 non-null     object
#  14  Behavioral Attributes          90 non-null     object
#  15  Socioeconomic Attributes       90 non-null     object
#  16  Psychological and Emotional    90 non-null     object
#  17  Technology Usage               90 non-null     object
#  18  Peer Interactions              90 non-null     object
#  19  Cognitive Attributes           100 non-null    object
#  20  Communication Skills           100 non-null    object
#  21  Learning Progression           100 non-null    object
# dtypes: float64(2), int64(2), object(18)
# memory usage: 17.3+ KB

# %%
df.describe()
# Out:
#        Student ID       Class       Marks  Attendance (%)
# count  100.000000  100.000000   77.000000       75.000000
# mean    50.500000   10.510000   78.909091       88.400000
# std     29.011492    1.123621   12.236896        8.006754
# min      1.000000    9.000000   60.000000       75.000000
# 25%     25.750000    9.750000   68.000000       80.500000
# 50%     50.500000   11.000000   79.000000       89.000000
# 75%     75.250000   11.250000   89.000000       95.500000
# max    100.000000   12.000000  100.000000      100.000000

# %%
df.isnull().sum()
# Out:
# Student ID                        0
# Name                              0
# Class                             0
# Marks                            23
# Family Background                10
# Family Educational Background     0
# Attendance (%)                   25
# Behavior                         24
# Viva Performance                 24
# Submission                       22
# Certification                    10
# Achievements                     10
# Hobby                            10
# Academic Attributes              10
# Behavioral Attributes            10
# Socioeconomic Attributes         10
# Psychological and Emotional      10
# Technology Usage                 10
# Peer Interactions                10
# Cognitive Attributes              0
# Communication Skills              0
# Learning Progression              0
# dtype: int64

# %%
#handlie the  missing values

# %%
# Fill numerical missing values with mean
num_imputer = SimpleImputer(strategy="mean")
df[df.select_dtypes(include=["number"]).columns] = num_imputer.fit_transform(df.select_dtypes(include=["number"]))

# Fill categorical missing values with mode
categorical_cols = df.select_dtypes(include=["object"]).columns

if len(categorical_cols) > 0:  # Check if there are any categorical columns
    cat_imputer = SimpleImputer(strategy="most_frequent")
    df[categorical_cols] = cat_imputer.fit_transform(df[categorical_cols])
else:
    print("No categorical columns found!")

# %%
df.isnull().sum()
# Out:
# Student ID                       0
# Name                             0
# Class                            0
# Marks                            0
# Family Background                0
# Family Educational Background    0
# Attendance (%)                   0
# Behavior                         0
# Viva Performance                 0
# Submission                       0
# Certification                    0
# Achievements                     0
# Hobby                            0
# Academic Attributes              0
# Behavioral Attributes            0
# Socioeconomic Attributes         0
# Psychological and Emotional      0
# Technology Usage                 0
# Peer Interactions                0
# Cognitive Attributes             0
# Communication Skills             0
# Learning Progression             0
# dtype: int64

# %%
df
# Out:
#     Student ID              Name  Class      Marks   Family Background  \
# 0          1.0        Rahul More    9.0  78.909091         Upper class
# 1          2.0    Aarav Deshmukh   10.0  62.000000         Upper class
# 2          3.0        Rahul More   11.0  90.000000         Upper class
# 3          4.0   Ananya Kulkarni    9.0  78.909091  Upper-middle class
# 4          5.0     Vishal Chavan   10.0  60.000000         Lower class
# ..         ...               ...    ...        ...                 ...
# 95        96.0     Meera Bhosale   12.0  89.000000  Upper-middle class
# 96        97.0  Aishwarya Sawant   10.0  78.909091         Lower class
# 97        98.0  Aishwarya Sawant   11.0  71.000000         Upper class
# 98        99.0     Meera Bhosale   12.0  79.000000  Upper-middle class
# 99       100.0       Arjun Joshi   10.0  66.000000         Lower class
#
#      Family Educational Background  Attendance (%)   Behavior  \
# 0      Father high school graduate            90.0       Poor
# 1      Mother high school graduate            88.4  Excellent
# 2      Father high school graduate            85.0       Good
# 3      Father high school graduate            97.0    Average
# 4   Both parents college graduates            87.0  Excellent
# ..                             ...             ...        ...
# 95  Both parents college graduates            81.0       Good
# 96     Father high school graduate            97.0       Poor
# 97     Father high school graduate            86.0       Good
# 98     Mother high school graduate            87.0  Excellent
# 99  Both parents college graduates            88.4       Poor
#
#    Viva Performance Submission  ...           Hobby Academic Attributes  \
# 0              Good       Late  ...         Reading           Marks: 60
# 1         Excellent       Late  ...         Reading           Marks: 62
# 2           Average       Late  ...  Playing Tennis           Marks: 90
# 3              Good    On time  ...  Playing Tennis           Marks: 65
# 4              Poor    On time  ...  Playing Tennis           Marks: 60
# ..              ...        ...  ...             ...                 ...
# 95        Excellent       Late  ...  Playing Tennis           Marks: 64
# 96             Poor    On time  ...       Traveling           Marks: 82
# 97        Excellent       Late  ...  Playing Guitar           Marks: 71
# 98             Poor    On time  ...  Playing Guitar           Marks: 79
# 99             Poor       Late  ...  Playing Tennis           Marks: 66
#
#     Behavioral Attributes           Socioeconomic Attributes  \
# 0   Time Management: Good        Socioeconomic: Middle class
# 1   Time Management: Good         Socioeconomic: Upper class
# 2   Time Management: Good        Socioeconomic: Middle class
# 3   Time Management: Good  Socioeconomic: Upper-middle class
# 4   Time Management: Good         Socioeconomic: Lower class
# ..                    ...                                ...
# 95  Time Management: Good         Socioeconomic: Upper class
# 96  Time Management: Good         Socioeconomic: Lower class
# 97  Time Management: Good         Socioeconomic: Upper class
# 98  Time Management: Good  Socioeconomic: Upper-middle class
# 99  Time Management: Good         Socioeconomic: Lower class
#
#       Psychological and Emotional             Technology Usage  \
# 0   Stress: Low, Confidence: High  EdTech: High, Internet: Yes
# 1   Stress: Low, Confidence: High  EdTech: High, Internet: Yes
# 2   Stress: Low, Confidence: High  EdTech: High, Internet: Yes
# 3   Stress: Low, Confidence: High  EdTech: High, Internet: Yes
# 4   Stress: Low, Confidence: High  EdTech: High, Internet: Yes
# ..                            ...                          ...
# 95  Stress: Low, Confidence: High  EdTech: High, Internet: Yes
# 96  Stress: Low, Confidence: High  EdTech: High, Internet: Yes
# 97  Stress: Low, Confidence: High  EdTech: High, Internet: Yes
# 98  Stress: Low, Confidence: High  EdTech: High, Internet: Yes
# 99  Stress: Low, Confidence: High  EdTech: High, Internet: Yes
#
#         Peer Interactions       Cognitive Attributes  \
# 0   Group Work: Excellent  Critical Thinking: Strong
# 1   Group Work: Excellent  Critical Thinking: Strong
# 2   Group Work: Excellent  Critical Thinking: Strong
# 3   Group Work: Excellent  Critical Thinking: Strong
# 4   Group Work: Excellent  Critical Thinking: Strong
# ..                    ...                        ...
# 95  Group Work: Excellent  Critical Thinking: Strong
# 96  Group Work: Excellent  Critical Thinking: Strong
# 97  Group Work: Excellent  Critical Thinking: Strong
# 98  Group Work: Excellent  Critical Thinking: Strong
# 99  Group Work: Excellent  Critical Thinking: Strong
#
#         Communication Skills Learning Progression
# 0   Communication: Excellent  Improvement: Steady
# 1   Communication: Excellent  Improvement: Steady
# 2   Communication: Excellent  Improvement: Steady
# 3   Communication: Excellent  Improvement: Steady
# 4   Communication: Excellent  Improvement: Steady
# ..                       ...                  ...
# 95  Communication: Excellent  Improvement: Steady
# 96  Communication: Excellent  Improvement: Steady
# 97  Communication: Excellent  Improvement: Steady
# 98  Communication: Excellent  Improvement: Steady
# 99  Communication: Excellent  Improvement: Steady
#
# [100 rows x 22 columns]

# %%
#distribution of marks
plt.figure(figsize=(8,5))
sns.histplot(df["Marks"],bins=20,kde=True)
plt.title("Marks Distribution")
plt.xlabel("marks")
plt.ylabel("count")
plt.show()

# %%
#correlation heatmap
df.columns
# Out:
# Index(['Student ID', 'Name', 'Class', 'Marks', 'Family Background',
#        'Family Educational Background', 'Attendance (%)', 'Behavior',
#        'Viva Performance', 'Submission', 'Certification', 'Achievements',
#        'Hobby', 'Academic Attributes', 'Behavioral Attributes',
#        'Socioeconomic Attributes', 'Psychological and Emotional',
#        'Technology Usage', 'Peer Interactions', 'Cognitive Attributes',
#        'Communication Skills', 'Learning Progression'],
#       dtype='object')

# %%
plt.figure(figsize=(10,8))
numerical_df=df.select_dtypes(include=["number"])
sns.heatmap(numerical_df.corr(),annot=True, cmap="coolwarm", fmt=".2f")
plt.title("feature correlation Heatmap")
plt.show()

# %%
#box ploter for find outlier
plt.figure(figsize=(10,6))
sns.boxplot(x=df["Marks"])
plt.title("box plot of arks (otlier detection)")
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.barplot(x="Attendance (%)",y="Marks",data=df)
plt.title("Attendance  vs Marks")
plt.xlabel("Attendance (%)")
plt.ylabel("Avarage Marks")
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.boxplot(x="Behavior",y="Marks",data=df)
plt.title("Behavior vas Marks")
plt.show()

# %%
df.isnull().sum()
# Out:
# Student ID                       0
# Name                             0
# Class                            0
# Marks                            0
# Family Background                0
# Family Educational Background    0
# Attendance (%)                   0
# Behavior                         0
# Viva Performance                 0
# Submission                       0
# Certification                    0
# Achievements                     0
# Hobby                            0
# Academic Attributes              0
# Behavioral Attributes            0
# Socioeconomic Attributes         0
# Psychological and Emotional      0
# Technology Usage                 0
# Peer Interactions                0
# Cognitive Attributes             0
# Communication Skills             0
# Learning Progression             0
# dtype: int64

# %%
df["Achievements"].isnull().sum()
# Out:
# 0

# %%
print(df["Achievements"].head())
# Out:
# 0    Science Fair Winner
# 1       Best Art Project
# 2    Science Fair Winner
# 3         Sports Captain
# 4    Top in Math Contest
# Name: Achievements, dtype: object

# %%
df["Achievements"]=df["Achievements"].fillna("unknown")

# %%
df["Achievements"].isnull().sum()
# Out:
# 0

# %%
#participation in extra activity

df["Achievements"].value_counts().plot.pie(
    autopct="%1.1f%%",figsize=(7,7),
    cmap="coolwarm"
  )
plt.title("participation in extra activities")
plt.show()

# %%
df.isnull()
# Out:
#     Student ID   Name  Class  Marks  Family Background  \
# 0        False  False  False  False              False
# 1        False  False  False  False              False
# 2        False  False  False  False              False
# 3        False  False  False  False              False
# 4        False  False  False  False              False
# ..         ...    ...    ...    ...                ...
# 95       False  False  False  False              False
# 96       False  False  False  False              False
# 97       False  False  False  False              False
# 98       False  False  False  False              False
# 99       False  False  False  False              False
#
#     Family Educational Background  Attendance (%)  Behavior  Viva Performance  \
# 0                           False           False     False             False
# 1                           False           False     False             False
# 2                           False           False     False             False
# 3                           False           False     False             False
# 4                           False           False     False             False
# ..                            ...             ...       ...               ...
# 95                          False           False     False             False
# 96                          False           False     False             False
# 97                          False           False     False             False
# 98                          False           False     False             False
# 99                          False           False     False             False
#
#     Submission  ...  Hobby  Academic Attributes  Behavioral Attributes  \
# 0        False  ...  False                False                  False
# 1        False  ...  False                False                  False
# 2        False  ...  False                False                  False
# 3        False  ...  False                False                  False
# 4        False  ...  False                False                  False
# ..         ...  ...    ...                  ...                    ...
# 95       False  ...  False                False                  False
# 96       False  ...  False                False                  False
# 97       False  ...  False                False                  False
# 98       False  ...  False                False                  False
# 99       False  ...  False                False                  False
#
#     Socioeconomic Attributes  Psychological and Emotional  Technology Usage  \
# 0                      False                        False             False
# 1                      False                        False             False
# 2                      False                        False             False
# 3                      False                        False             False
# 4                      False                        False             False
# ..                       ...                          ...               ...
# 95                     False                        False             False
# 96                     False                        False             False
# 97                     False                        False             False
# 98                     False                        False             False
# 99                     False                        False             False
#
#     Peer Interactions  Cognitive Attributes  Communication Skills  \
# 0               False                 False                 False
# 1               False                 False                 False
# 2               False                 False                 False
# 3               False                 False                 False
# 4               False                 False                 False
# ..                ...                   ...                   ...
# 95              False                 False                 False
# 96              False                 False                 False
# 97              False                 False                 False
# 98              False                 False                 False
# 99              False                 False                 False
#
#     Learning Progression
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ..                   ...
# 95                 False
# 96                 False
# 97                 False
# 98                 False
# 99                 False
#
# [100 rows x 22 columns]

# %%
#feature engineering
#converting the categorical variables into numerical using label encoding
label_enc=LabelEncoder()
categorical_cols=df.select_dtypes(include=["object"]).columns.tolist()

for col in categorical_cols:
  df[col]=label_enc.fit_transform(df[col])

scaler=StandardScaler()#Standardization ensures that all features are on the same scale to improve model performance.
df[df.columns]=scaler.fit_transform(df)

# %%
#dplit dataset for 80%traning & 20% testing
#feature feature x and y

x=df.drop("Marks",axis=1)#independent variable
y=df["Marks"]#Target Variable

x_train,x_test,y_train,y_test=train_test_split(x,y ,test_size=0.2,random_state=42)

print("Traning Data Shape:",x_train.shape)
print("Testing Data Shape:",x_test.shape)
# Out:
# Traning Data Shape: (80, 21)
# Testing Data Shape: (20, 21)

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(x_train, y_train)

# Model Evaluation
y_pred = rf_model.predict(x_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Random Forest Regressor Performance:")
print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"R² Score: {r2}")
# Out:
# Random Forest Regressor Performance:
# MAE: 0.49291132007762073
# MSE: 0.4248302683903834
# R² Score: -0.015830374988060614

# %%
from sklearn.svm import SVR

svr_model=SVR(kernel="linear")
svr_model.fit(x_train,y_train)
y_pred_svr=svr_model.predict(x_test)

print("SVR  R² Score:",r2_score(y_test,y_pred_svr))
# Out:
# SVR  R² Score: -1.2075888316652224

# %%
with open("C:\\Users\\jadha\\OneDrive\\Desktop\\PBL-project\\rf_model.pkl", "rb") as file:
    rf_model = pickle.load(file)

# %%
# Check actual vs predicted values
comparison_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(comparison_df.head(10))  # Display first 10 results

# Scatter plot of Actual vs Predicted
plt.figure(figsize=(8,6))
sns.scatterplot(x=y_test, y=y_pred, alpha=0.7)
plt.xlabel("Actual Marks")
plt.ylabel("Predicted Marks")
plt.title("Actual vs Predicted Marks")
plt.show()

# Feature Importance from Random Forest
feature_importance = pd.Series(rf_model.feature_importances_, index=x_train.columns)
plt.figure(figsize=(10,6))
feature_importance.nlargest(10).plot(kind='barh', colormap='viridis')
plt.title("Top 10 Feature Importance in RandomForest")
plt.xlabel("Importance Score")
plt.ylabel("Features")
plt.show()

# Trying Linear Regression for comparison
lr_model = LinearRegression()
lr_model.fit(x_train, y_train)
y_pred_lr = lr_model.predict(x_test)

print("Linear Regression Performance:")
print(f"MAE: {mean_absolute_error(y_test, y_pred_lr)}")
print(f"MSE: {mean_squared_error(y_test, y_pred_lr)}")
print(f"R² Score: {r2_score(y_test, y_pred_lr)}")
# Out:
#     Actual  Predicted
# 83     0.0  -0.719407
# 53     0.0   0.283434
# 70     0.0   0.061016
# 45     0.0  -0.384161
# 44     0.0  -1.513124
# 39     0.0  -1.013834
# 22     0.0  -0.115214
# 80     0.0  -0.907482
# 10     0.0  -0.057778
# 0      0.0  -1.009828
# Linear Regression Performance:
# MAE: 0.526421792241795
# MSE: 0.43433157069333417
# R² Score: -0.03854935760163536
